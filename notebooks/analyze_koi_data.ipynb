# %%
import pandas as pd
koi_df = pd.read_csv("../data/cumulative_2025.09.21_17.22.39.csv", skiprows=144)
koi_df.head()
# Out:
#    rowid     kepid kepoi_name   kepler_name koi_disposition koi_vet_stat  \
# 0      1  10797460  K00752.01  Kepler-227 b       CONFIRMED         Done
# 1      2  10797460  K00752.02  Kepler-227 c       CONFIRMED         Done
# 2      3  10811496  K00753.01           NaN       CANDIDATE         Done
# 3      4  10848459  K00754.01           NaN  FALSE POSITIVE         Done
# 4      5  10854555  K00755.01  Kepler-664 b       CONFIRMED         Done
#
#   koi_vet_date koi_pdisposition  koi_score  koi_fpflag_nt  ...  \
# 0   2018-08-16        CANDIDATE      1.000              0  ...
# 1   2018-08-16        CANDIDATE      0.969              0  ...
# 2   2018-08-16        CANDIDATE      0.000              0  ...
# 3   2018-08-16   FALSE POSITIVE      0.000              0  ...
# 4   2018-08-16        CANDIDATE      1.000              0  ...
#
#    koi_dicco_mdec  koi_dicco_mdec_err  koi_dicco_msky koi_dicco_msky_err  \
# ...

# %%
koi_df.shape
# Out:
# (9564, 141)

# %%
koi_df.describe()
# Out:
#              rowid         kepid    koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# count  9564.000000  9.564000e+03  8054.000000    9564.000000    9564.000000
# mean   4782.500000  7.690628e+06     0.480829       0.208595       0.232748
# std    2761.033321  2.653459e+06     0.476928       4.767290       0.422605
# min       1.000000  7.574500e+05     0.000000       0.000000       0.000000
# 25%    2391.750000  5.556034e+06     0.000000       0.000000       0.000000
# 50%    4782.500000  7.906892e+06     0.334000       0.000000       0.000000
# 75%    7173.250000  9.873066e+06     0.998000       0.000000       0.000000
# max    9564.000000  1.293514e+07     1.000000     465.000000       1.000000
#
#        koi_fpflag_co  koi_fpflag_ec     koi_period  koi_period_err1  \
# count    9564.000000    9564.000000    9564.000000      9110.000000
# mean        0.197512       0.120033      75.671358         0.002148
# std         0.398142       0.325018    1334.744046         0.008236
# ...

# %%
df = koi_df[['koi_period', 'koi_time0bk', 'koi_duration', 'koi_depth', 'koi_prad', 'koi_insol', 'koi_teq', 'koi_steff', 'koi_slogg', 'koi_srad', 'koi_disposition']]
df
# Out:
#       koi_period  koi_time0bk  koi_duration  koi_depth  koi_prad  koi_insol  \
# 0       9.488036   170.538750       2.95750      615.8      2.26      93.59
# 1      54.418383   162.513840       4.50700      874.8      2.83       9.11
# 2      19.899140   175.850252       1.78220    10829.0     14.60      39.30
# 3       1.736952   170.307565       2.40641     8079.2     33.46     891.96
# 4       2.525592   171.595550       1.65450      603.3      2.75     926.16
# ...          ...          ...           ...        ...       ...        ...
# 9559    0.527699   131.705093       3.22210     1579.2     29.35    4500.53
# 9560    1.739849   133.001270       3.11400       48.5      0.72    1585.81
# 9561    0.681402   132.181750       0.86500      103.6      1.07    5713.41
# 9562  333.486169   153.615010       3.19900      639.1     19.30      22.68
# 9563    4.856035   135.993300       3.07800       76.7      1.05     607.42
#
# ...

# %%
df['koi_disposition'].value_counts()
# Out:
# koi_disposition
# FALSE POSITIVE    4839
# CONFIRMED         2746
# CANDIDATE         1979
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['koi_period', 'koi_time0bk', 'koi_duration', 'koi_depth', 'koi_prad',
#        'koi_insol', 'koi_teq', 'koi_steff', 'koi_slogg', 'koi_srad',
#        'koi_disposition'],
#       dtype='object')

# %%
df = df.rename(columns={
    'koi_period': 'orbital_period',
    'koi_time0bk': 'transit_epoch',
    'koi_duration': 'transit_duration',
    'koi_depth': 'transit_depth',
    'koi_prad': 'planet_radius',
    'koi_insol': 'insolation_flux',
    'koi_teq': 'equilibrium_temp',
    'koi_steff': 'effective_temp',
    'koi_slogg': 'surface_gravity',
    'koi_srad': 'stellar_radius',
    'koi_disposition': 'disposition'
})
df['dataset'] = 'KOI'
df
# Out:
#       orbital_period  transit_epoch  transit_duration  transit_depth  \
# 0           9.488036     170.538750           2.95750          615.8
# 1          54.418383     162.513840           4.50700          874.8
# 2          19.899140     175.850252           1.78220        10829.0
# 3           1.736952     170.307565           2.40641         8079.2
# 4           2.525592     171.595550           1.65450          603.3
# ...              ...            ...               ...            ...
# 9559        0.527699     131.705093           3.22210         1579.2
# 9560        1.739849     133.001270           3.11400           48.5
# 9561        0.681402     132.181750           0.86500          103.6
# 9562      333.486169     153.615010           3.19900          639.1
# 9563        4.856035     135.993300           3.07800           76.7
#
#       planet_radius  insolation_flux  equilibrium_temp  effective_temp  \
# ...

# %%
df = df.drop(columns=['insolation_flux', 'equilibrium_temp'])
df
# Out:
#       orbital_period  transit_epoch  transit_duration  transit_depth  \
# 0           9.488036     170.538750           2.95750          615.8
# 1          54.418383     162.513840           4.50700          874.8
# 2          19.899140     175.850252           1.78220        10829.0
# 3           1.736952     170.307565           2.40641         8079.2
# 4           2.525592     171.595550           1.65450          603.3
# ...              ...            ...               ...            ...
# 9559        0.527699     131.705093           3.22210         1579.2
# 9560        1.739849     133.001270           3.11400           48.5
# 9561        0.681402     132.181750           0.86500          103.6
# 9562      333.486169     153.615010           3.19900          639.1
# 9563        4.856035     135.993300           3.07800           76.7
#
#       planet_radius  effective_temp  surface_gravity  stellar_radius  \
# ...
